# %% [markdown]
# ### Modelagem Conceitual, lógica e física
# - Precisamos dos modelos de dados para descrever, com mais detalhes a estrutura de uma banco de dados;
# - Esses modelos serão usados pelos desenvolvedores;
# - E também como documentação do projeto.
#
# ### Modelagem conceitual
# - Técnicas para construir modelos conceituais base de dados. (Peter Chen)
# - A apresentação gráfica o DER (Diagrama de Entidade e Relacionamento)
#
# Exemplo
# tipo_produtos 1     [ tipProd ]      N produtos
# codigo-descrição                   codigo-descrição codigo_tipo_prduto
#
# Cardionalidade: Unidade de realacionamento entre entidades ( 1 - N / N - N / - 1)
#
# Relacionamento (DER)
# - Entidade
# - Atributo
# - Relacionamento
# - Generalização/Especialização
#
# Entidade
# - Mer - retângulo
# - Dentro do retângulo - nome
# - InstÂncia ou ocorrência da Entidade Pessoa Maria, Carlos e Eduardo
#
# Atributo
# - São os dados associados a uma instância da entidade
# Exemplo:
# Entidade: Pessoa
# Atributo: CPF
#
# ### Tipos de Atributos
# - Atributo Simples
# Atributos simples são indivisíveis, ou seja, são atributos atômicos, um exemplo seria o atributo CPF, ele não pode ser dividido em partes menores para formar outros atributos, ele é indivisível.
#
# - Atributo Composto
# Atributos Compostos podem ser divididos em partes menores, que representam outros atributos, como o atributo endereço, ele pode ser subdividido em atributos menores, como, por exemplo, cidade, estado, rua, CEP.
#
# - Atributo Multivalorado
# Um atributo Multivalorado pode ter um ou N (vários) valores associados a ele, como, por exemplo, o atributo telefone de um cliente, ele pode ter um ou vários telefones.
#
# - Atributo Derivado
# Atributos derivados dependem de outro atributo ou até mesmo outra entidade para existir, como, por exemplo, o atributo idade e o atributo data de nascimento, para descobrimos a idade de uma pessoa precisamos da sua data de nascimento, então, consideramos o atributo idade como derivado do atributo data de nascimento.
#
# - Atributo Chave
#
# O atributo chave é utilizado para identificar de forma única uma entidade, ou seja, os valores associados a esse atributo são distintos dentre o conjunto de entidades. Como exemplo, podemos utilizar o CPF de uma pessoa, ele é único e pode ser utilizado como atributo chave, já que cada pessoa recebe um número de CPF distinto.
#
# - Simples: São chamados de atômicos. Não podem ser dividos
# Ex: preço. quantidade, cor ...
#
# - Compostos: São aqueles que podem ser derivados em partes menores:
# Ex: endereço pode ser dividido em rua, número, complemento...
#
# - Multivalorados: São aqueles que possuem uma ou mais valores para o mesmo atributo
# Ex: Telefone. Uma pessoa poderá possuir mais de 1 telefone.
#
# - > Transformar atributo em entidade para solucionar o problema do multivalorado
#
# ### Atributos Identificadores
# Chaves "únicas" e "não únicas"
#
# Chaves Estrangeiras: são campos ou atributos que estabelecem o relacionamento com outra tabela através da CHAVE PRIMÁRIA
#
# ### Relacionamentos
# - Associações entre as entidades
# - Entidade Pessoa computador
# - Representa uma ação: Tipo, entidade , pessoa. Usa- Computador
